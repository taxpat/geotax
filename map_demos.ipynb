# %%
import pandas as pd
import random
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import json
from matplotlib.patches import Patch
from matplotlib.colors import ListedColormap

# %%
# read in state_map.json as gjson
with open('state_map.json') as f:
    gjson = json.load(f)

gdf = gpd.GeoDataFrame.from_features(gjson, crs='EPSG:4326')

# Plot the GeoDataFrame
gdf.plot()

# Display the plot
plt.show()

# %%
# read in state_map.json as gjson
with open('state_map_w_abb.json') as f:
    gjson = json.load(f)

gdf = gpd.GeoDataFrame.from_features(gjson, crs='EPSG:4326')

# for lon, lat, abbrev in zip(gdf['ab_lon'], gdf['ab_lat'], gdf['STUSPS']):
#     ax.annotate(abbrev, xy=(lon, lat), xytext=(0, 3), textcoords='offset points', ha='center', fontsize=10)

# Plot the GeoDataFrame
gdf.plot()

# Display the plot
plt.show()
